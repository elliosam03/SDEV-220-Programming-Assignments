# %%
"""
Author: Sam Elliott
File name: Dean's List or Honor Roll
Description: To determine whether a student has made the Dean's List or the Honor Roll or neither 
"""

while True:
    last_name = input("Enter student's last name or (ZZZ) to quit: ")
    if last_name == "ZZZ":
        break

    first_name = input("Enter student's first name: ")

    GPA = float(input("Enter student's GPA: "))

    if GPA >= 3.5:
        print ("This student has made the Dean's List")
    elif GPA >= 3.25:
        print ("This student has made the Honor Roll")
    else:
        print ("This student should've studied more. tsk tsk")
# Out:
# Enter student's last name or (ZZZ) to quit:  aa
# Enter student's first name:  aaa
# Enter student's GPA:  3
# This student should've studied more. tsk tsk
# Enter student's last name or (ZZZ) to quit:  bb
# Enter student's first name:  bbb
# Enter student's GPA:  3.25
# This student has made the Honor Roll
# Enter student's last name or (ZZZ) to quit:  cc
# Enter student's first name:  ccc
# Enter student's GPA:  3.4
# This student has made the Honor Roll
# Enter student's last name or (ZZZ) to quit:  dd
# Enter student's first name:  ddd
# Enter student's GPA:  3.5
# This student has made the Dean's List
# Enter student's last name or (ZZZ) to quit:  ee
# Enter student's first name:  eee
# Enter student's GPA:  4
# This student has made the Dean's List
# Enter student's last name or (ZZZ) to quit:  ZZZ
