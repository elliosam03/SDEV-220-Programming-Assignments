# %%
#4.1
secret = 5
guess = 5

if guess > secret:
    print ('too high')
elif guess < secret:
    print ('too low')
else:
    print ('just right')
# Out:
# just right

# %%
#4.2
small = True
green = True

if small:
    if green:
        print ('pea')
    else:
        print ('cherry')
else:
    if green:
            print ('watermelon')
    else:
        print ('pumpkin')
# Out:
# pea

# %%
#6.1
list = [3, 2, 1, 0]

for x in list:
    print (x)
# Out:
# 3
# 2
# 1
# 0

# %%
#6.2
guess_me = 7
number = 1

while True:
    if number < guess_me:
        print('too low')
    elif number == guess_me:
        print('found it!')
        break
    else:
        print('oops')
        break
    number += 1
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!

# %%
#6.3
guess_me = 5

for number in range(10):
    if number < guess_me:
        print('too low')
    elif number == guess_me:
        print('found it!')
        break
    else:
        print('oops')
        break
    number += 1
# Out:
# too low
# too low
# too low
# too low
# too low
# found it!
