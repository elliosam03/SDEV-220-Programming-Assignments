# %%
#7.4
things = ["mozzarella", "cinderella", "salmonella"]
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
#7.5
things = ["mozzarella", "Cinderella", "salmonella"]
print(things)
print("All elements portray what is found within the list of things")
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']
# All elements portray what is found within the list of things

# %%
#7.6
things = ["MOZZARELLA", "cinderella", "salmonella"]
print(things)
# Out:
# ['MOZZARELLA', 'cinderella', 'salmonella']

# %%
#7.7
things = ["mozzarella", "cinderella"]
print(things)
print("Yay. No more disease.")
# Out:
# ['mozzarella', 'cinderella']
# Yay. No more disease.

# %%
#9.1
def good():
    HP_character_list = ["Harry", "Ron", "Hermione"]
    print(HP_character_list)
good()
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
#9.2
def get_odds():    
    for num in range(10):
        if num % 2 != 0:
            yield num

odds_gen = get_odds()
for i, value in enumerate(odds_gen, start=1):
    if i == 3:
        print("Third value returned:", value)
# Out:
# Third value returned: 5
